# %%
from scipy.integrate import odeint
import numpy as np
import matplotlib.pyplot as plt
from pandas import DataFrame

def odes(x,t):
    #constan
    a = 1
    b = 1
    gama = 1
    r = 0
    k = 0
    s = 0
    f = 0
    u = 0
    mu1 = 0
    mu2 = 0
    mu3 = 0
    mu4 = 0
    p1 = 0
    p2 = 0
    p3 = 0
    p4 = 1
    q1 = 0
    q2 = 0
    q3 = 0
    

    #vector element
    A = x[0]
    B = x[1]
    C = x[2]
    D = x[3]
    
    # persamaan 
    dAdt = u - (a + r + mu1 + p1)*A - k*A*C + q1*D
    dBdt = a*A - (b + s + mu2 + p2)*B - f*B*D + q2*D
    dCdt = r*A + b*B - (gama + mu3 + p3)*C + k*A*C + q3*D
    dDdt = gama*C - (q1+q2+q3+mu4+p4)*D + f*B*D + s*B
    
    return (dAdt, dBdt, dCdt, dDdt)

#nilai awal (jumlah populasi awal)
x0=[10,10,10,10] 

#grafik waktu
t = np.linspace(0,20,10000)
x = odeint(odes,x0,t)

A = x[:,0]
B = x[:,1]
C = x[:,2]
D = x[:,3]

data={'t':t,'A':A, 'B':B, 'C':C, 'D':D}
print(DataFrame(data))

#plot 
plt.figure(figsize=(10,6))
plt.plot(t,A, label='Mengambil mata kuliah maksimal tahun ke 1', color='green')
plt.plot(t,B, label='Mengambil mata kuliah maksimal tahun ke 2', color='red')
plt.plot(t,C, label='Mengambil mata kuliah maksimal tahun ke 3', color='blue')
plt.plot(t,D, label='Mengambil mata kuliah maksimal tahun ke 4', color='yellow')
plt.legend()
plt.grid()
plt.title("Kasus 1")
plt.savefig('Kasus 1.png',dpi = 500)
plt.show()
# Out:
#               t             A             B          C          D
# 0      0.000000  1.000000e+01  1.000000e+01  10.000000  10.000000
# 1      0.002000  9.980018e+00  9.999980e+00  10.000000  10.000000
# 2      0.004000  9.960076e+00  9.999920e+00  10.000000  10.000000
# 3      0.006001  9.940174e+00  9.999821e+00  10.000000  10.000000
# 4      0.008001  9.920311e+00  9.999682e+00   9.999999  10.000000
# ...         ...           ...           ...        ...        ...
# 9995  19.991999  2.077952e-08  4.362051e-07   0.000005   0.000032
# 9996  19.993999  2.073796e-08  4.353746e-07   0.000005   0.000032
# 9997  19.996000  2.069648e-08  4.345456e-07   0.000005   0.000032
# 9998  19.998000  2.065509e-08  4.337182e-07   0.000005   0.000032
# 9999  20.000000  2.061378e-08  4.328924e-07   0.000005   0.000032
#
# [10000 rows x 5 columns]

# %% [markdown]
# Interpretasi
#
# nilai awal semua kelas yaitu 10, pada kasus 1 ini diasumsikan bahwa alur akademik mahasiswa sesuai yg diharapkan (tanpa ada maba yang masuk, tanpa pengulangan, tanpa ada yang keluar, lulus hanya di tahun ke-4, tanpa adanya interkasi, dan berpindah sesuai urutan). dari grafik dapat dilihat bahwa banyaknya mahasiswa yang mengambil mata kuliah maksimal tahun ke i (dengan i = 1,2,3,4) akan menuju ke titik equilibriumnya yaitu (0, 0, 0, 0).

# %% [markdown]
# u = 0
# yang keluar 0
# yang ngulang 0 (lulus hanya di tahun 4)
# ga ada interaksi 0
#
# grafik 1(yang urut)
# grafik 2( ada maba )
#
# grafik 3(u = 0 , ada sistem pengulangan matkul p =/ 0)
# grafik 4(ada maba, ada sistem pengulangan matkul p =/ 0)
#
# grafik 5(u = 0 , ada interaksi)
# grafik 6(ada maba, ada interaksi)
#
# grafik 7(u = 0, ada interaksi ada pengulangan
# grafik 8(ada maba
#
# grafik 9

# %%
from scipy.integrate import odeint
import numpy as np
import matplotlib.pyplot as plt
from pandas import DataFrame

def odes(x,t):
    #constan
    a = 1
    b = 1
    gama = 1
    r = 0
    k = 0
    s = 0
    f = 0
    u = 9
    mu1 = 0
    mu2 = 0
    mu3 = 0
    mu4 = 0
    p1 = 0
    p2 = 0
    p3 = 0
    p4 = 1
    q1 = 0
    q2 = 0
    q3 = 0
    

    #vector element
    A = x[0]
    B = x[1]
    C = x[2]
    D = x[3]
    
    # persamaan 
    dAdt = u - (a + r + mu1 + p1)*A - k*A*C + q1*D
    dBdt = a*A - (b + s + mu2 + p2)*B - f*B*D + q2*D
    dCdt = r*A + b*B - (gama + mu3 + p3)*C + k*A*C + q3*D
    dDdt = gama*C - (q1+q2+q3+mu4+p4)*D + f*B*D + s*B
    
    return (dAdt, dBdt, dCdt, dDdt)

#nilai awal (jumlah populasi awal)
x0=[10,10,10,10] 

#grafik waktu
t = np.linspace(0,20,10000)
x = odeint(odes,x0,t)

A = x[:,0]
B = x[:,1]
C = x[:,2]
D = x[:,3]

data={'t':t,'A':A, 'B':B, 'C':C, 'D':D}
print(DataFrame(data))

#plot 
plt.figure(figsize=(10,6))
plt.plot(t,A, label='Mengambil mata kuliah maksimal tahun ke 1', color='green')
plt.plot(t,B, label='Mengambil mata kuliah maksimal tahun ke 2', color='red')
plt.plot(t,C, label='Mengambil mata kuliah maksimal tahun ke 3', color='blue')
plt.plot(t,D, label='Mengambil mata kuliah maksimal tahun ke 4', color='yellow')
plt.legend()
plt.grid()
plt.title("Kasus 2.2")
plt.savefig('Kasus 2.2 .png',dpi = 500)
plt.show()
# Out:
#               t          A          B     C          D
# 0      0.000000  10.000000  10.000000  10.0  10.000000
# 1      0.002000   9.998002   9.999998  10.0  10.000000
# 2      0.004000   9.996008   9.999992  10.0  10.000000
# 3      0.006001   9.994017   9.999982  10.0  10.000000
# 4      0.008001   9.992031   9.999968  10.0  10.000000
# ...         ...        ...        ...   ...        ...
# 9995  19.991999   9.000000   9.000000   9.0   9.000003
# 9996  19.993999   9.000000   9.000000   9.0   9.000003
# 9997  19.996000   9.000000   9.000000   9.0   9.000003
# 9998  19.998000   9.000000   9.000000   9.0   9.000003
# 9999  20.000000   9.000000   9.000000   9.0   9.000003
#
# [10000 rows x 5 columns]

# %% [markdown]
# Interpretasi
#
# nilai awal semua kelas yaitu 10, pada kasus 2 ini diasumsikan bahwa alur akademik mahasiswa sesuai yg diharapkan dan terdapat maba yang masuk (tanpa pengulangan, tanpa ada yang keluar, lulus hanya di tahun ke-4, tanpa adanya interkasi, dan berpindah sesuai urutan).
#
# dengan u = 11 (banyaknya mahasiswa baru =11) dari grafik dapat dilihat bahwa banyaknya mahasiswa yang mengambil mata kuliah maksimal tahun ke i (dengan i = 1,2,3,4) akan menuju ke titik (11,11,11,11)
#
# dengan u = 9 (dengan u = 11 (banyaknya mahasiswa baru =9) dari grafik dapat dilihat bahwa banyaknya mahasiswa yang mengambil mata kuliah maksimal tahun ke i (dengan i = 1,2,3,4) akan menuju ke titik (9,9,9,9)
#
# dalam kasus 2 ini dapat disimpulkan apabila terdapat mahasiswa baru, maka grafik tidak selalu menuju titik yang sama

# %%
from scipy.integrate import odeint
import numpy as np
import matplotlib.pyplot as plt
from pandas import DataFrame

def odes(x,t):
    #constan
    a = 1
    b = 1
    gama = 1
    r = 0
    k = 0
    s = 0
    f = 0
    u = 0
    mu1 = 0
    mu2 = 0
    mu3 = 0
    mu4 = 0
    p1 = 0
    p2 = 0
    p3 = 0
    p4 = 0.1
    q1 = 0.3
    q2 = 0.3
    q3 = 0.3
    

    #vector element
    A = x[0]
    B = x[1]
    C = x[2]
    D = x[3]
    
    # persamaan 
    dAdt = u - (a + r + mu1 + p1)*A - k*A*C + q1*D
    dBdt = a*A - (b + s + mu2 + p2)*B - f*B*D + q2*D
    dCdt = r*A + b*B - (gama + mu3 + p3)*C + k*A*C + q3*D
    dDdt = gama*C - (q1+q2+q3+mu4+p4)*D + f*B*D + s*B
    
    return (dAdt, dBdt, dCdt, dDdt)

#nilai awal (jumlah populasi awal)
x0=[10,10,10,10] 

#grafik waktu
t = np.linspace(0,200,10000)
x = odeint(odes,x0,t)

A = x[:,0]
B = x[:,1]
C = x[:,2]
D = x[:,3]

data={'t':t,'A':A, 'B':B, 'C':C, 'D':D}
print(DataFrame(data))

#plot 
plt.figure(figsize=(10,6))
plt.plot(t,A, label='Mengambil mata kuliah maksimal tahun ke 1', color='green')
plt.plot(t,B, label='Mengambil mata kuliah maksimal tahun ke 2', color='red')
plt.plot(t,C, label='Mengambil mata kuliah maksimal tahun ke 3', color='blue')
plt.plot(t,D, label='Mengambil mata kuliah maksimal tahun ke 4', color='yellow')
plt.legend()
plt.grid()
plt.title("Kasus 3")
plt.savefig('Kasus 3.png',dpi = 500)
plt.show()
# Out:
#                t          A          B          C          D
# 0       0.000000  10.000000  10.000000  10.000000  10.000000
# 1       0.020002   9.861378  10.058029  10.059994  10.000596
# 2       0.040004   9.725509  10.112199  10.119918  10.002368
# 3       0.060006   9.592344  10.162646  10.179704  10.005290
# 4       0.080008   9.461837  10.209504  10.239290  10.009336
# ...          ...        ...        ...        ...        ...
# 9995  199.919992   0.004488   0.009136   0.013949   0.014446
# 9996  199.939994   0.004485   0.009130   0.013940   0.014436
# 9997  199.959996   0.004482   0.009123   0.013930   0.014426
# 9998  199.979998   0.004479   0.009117   0.013920   0.014416
# 9999  200.000000   0.004476   0.009111   0.013911   0.014406
#
# [10000 rows x 5 columns]

# %% [markdown]
# Interpretasi
#
# nilai awal semua kelas yaitu 10, pada kasus 3 ini diasumsikan bahwa alur akademik mahasiswa sesuai yg diharapkan dan ada sistem pengulangan mata kuliah dan lulus hanya di tahun ke 4.(tanpa ada maba yang masuk, tanpa ada yang keluar, tanpa adanya interkasi). dari grafik dapat dilihat bahwa banyaknya mahasiswa yang mengambil mata kuliah maksimal tahun ke i (dengan i = 1,2,3,4) akan menuju ke titik equilibriumnya yaitu (0, 0, 0, 0).

# %%
from scipy.integrate import odeint
import numpy as np
import matplotlib.pyplot as plt
from pandas import DataFrame

def odes(x,t):
    #constan
    a = 1
    b = 1
    gama = 1
    r = 0
    k = 0
    s = 0
    f = 0
    u = 9
    mu1 = 0
    mu2 = 0
    mu3 = 0
    mu4 = 0
    p1 = 0
    p2 = 0
    p3 = 0
    p4 = 0.1
    q1 = 0.3
    q2 = 0.3
    q3 = 0.3
    

    #vector element
    A = x[0]
    B = x[1]
    C = x[2]
    D = x[3]
    
    # persamaan 
    dAdt = u - (a + r + mu1 + p1)*A - k*A*C + q1*D
    dBdt = a*A - (b + s + mu2 + p2)*B - f*B*D + q2*D
    dCdt = r*A + b*B - (gama + mu3 + p3)*C + k*A*C + q3*D
    dDdt = gama*C - (q1+q2+q3+mu4+p4)*D + f*B*D + s*B
    
    return (dAdt, dBdt, dCdt, dDdt)

#nilai awal (jumlah populasi awal)
x0=[10,10,10,10] 

#grafik waktu
t = np.linspace(0,200,10000)
x = odeint(odes,x0,t)

A = x[:,0]
B = x[:,1]
C = x[:,2]
D = x[:,3]

data={'t':t,'A':A, 'B':B, 'C':C, 'D':D}
print(DataFrame(data))

#plot 
plt.figure(figsize=(10,6))
plt.plot(t,A, label='Mengambil mata kuliah maksimal tahun ke 1', color='green')
plt.plot(t,B, label='Mengambil mata kuliah maksimal tahun ke 2', color='red')
plt.plot(t,C, label='Mengambil mata kuliah maksimal tahun ke 3', color='blue')
plt.plot(t,D, label='Mengambil mata kuliah maksimal tahun ke 4', color='yellow')
plt.legend()
plt.grid()
plt.title("Kasus 4")
plt.savefig('Kasus 4.png',dpi = 500)
plt.show()
# Out:
#                t          A          B          C          D
# 0       0.000000  10.000000  10.000000  10.000000  10.000000
# 1       0.020002  10.039608  10.059806  10.060006  10.000596
# 2       0.040004  10.078438  10.119211  10.120011  10.002369
# 3       0.060006  10.116514  10.178215  10.180014  10.005295
# 4       0.080008  10.153856  10.236818  10.240014  10.009351
# ...          ...        ...        ...        ...        ...
# 9995  199.919992  35.973556  62.946171  89.917810  89.914884
# 9996  199.939994  35.973574  62.946208  89.917867  89.914942
# 9997  199.959996  35.973592  62.946245  89.917923  89.915001
# 9998  199.979998  35.973611  62.946282  89.917980  89.915059
# 9999  200.000000  35.973629  62.946318  89.918036  89.915118
#
# [10000 rows x 5 columns]

# %% [markdown]
# Interpretasi
#
# nilai awal semua kelas yaitu 10, pada kasus 4 ini diasumsikan bahwa alur akademik mahasiswa sesuai yg diharapkan dan ada sistem pengulangan mata kuliah dan lulus hanya di tahun ke , terdapat maba yang masuk, tanpa ada yang keluar, tanpa adanya interkasi. dengan u = 9 dari grafik dapat dilihat bahwa banyaknya mahasiswa yang mengambil mata kuliah maksimal tahun ke i (dengan i = 1,2,3,4) akan menuju ke titik yang berbeda beda.

# %%
from scipy.integrate import odeint
import numpy as np
import matplotlib.pyplot as plt
from pandas import DataFrame

def odes(x,t):
    #constan
    a = 0.6
    b = 0.6
    gama = 0.6
    r = 0.2
    k = 0.075
    s = 0.2
    f = 0.075
    u = 0
    mu1 = 0.05
    mu2 = 0.025
    mu3 = 0.05
    mu4 = 0.01
    p1 = 0.05
    p2 = 0.075
    p3 = 0.2
    p4 = 0.4
    q1 = 0.075
    q2 = 0.2
    q3 = 0.2
    

    #vector element
    A = x[0]
    B = x[1]
    C = x[2]
    D = x[3]
    
    # persamaan 
    dAdt = u - (a + r + mu1 + p1)*A - k*A*C + q1*D
    dBdt = a*A - (b + s + mu2 + p2)*B - f*B*D + q2*D
    dCdt = r*A + b*B - (gama + mu3 + p3)*C + k*A*C + q3*D
    dDdt = gama*C - (q1+q2+q3+mu4+p4)*D + f*B*D + s*B
    
    return (dAdt, dBdt, dCdt, dDdt)

#nilai awal (jumlah populasi awal)
x0=[10,10,10,10] 

#grafik waktu
t = np.linspace(0,20,10000)
x = odeint(odes,x0,t)

A = x[:,0]
B = x[:,1]
C = x[:,2]
D = x[:,3]

data={'t':t,'A':A, 'B':B, 'C':C, 'D':D}
print(DataFrame(data))

#plot 
plt.figure(figsize=(10,6))
plt.plot(t,A, label='Mengambil mata kuliah maksimal tahun ke 1', color='green')
plt.plot(t,B, label='Mengambil mata kuliah maksimal tahun ke 2', color='red')
plt.plot(t,C, label='Mengambil mata kuliah maksimal tahun ke 3', color='blue')
plt.plot(t,D, label='Mengambil mata kuliah maksimal tahun ke 4', color='yellow')
plt.legend()
plt.grid()
plt.title("Kasus 5")
plt.savefig('Kasus 5.png',dpi = 500)
plt.show()
# Out:
#               t          A          B          C          D
# 0      0.000000  10.000000  10.000000  10.000000  10.000000
# 1      0.002000   9.968536   9.983000  10.017963  10.013294
# 2      0.004000   9.937152   9.966004  10.035847  10.026574
# 3      0.006001   9.905846   9.949012  10.053652  10.039839
# 4      0.008001   9.874619   9.932024  10.071379  10.053089
# ...         ...        ...        ...        ...        ...
# 9995  19.991999   0.006043   0.021882   0.042883   0.050119
# 9996  19.993999   0.006039   0.021869   0.042859   0.050090
# 9997  19.996000   0.006036   0.021857   0.042835   0.050062
# 9998  19.998000   0.006033   0.021845   0.042811   0.050034
# 9999  20.000000   0.006029   0.021833   0.042787   0.050005
#
# [10000 rows x 5 columns]

# %% [markdown]
# Interpretasi
#
# nilai awal semua kelas yaitu 10, pada kasus 5 ini diasumsikan bahwa alur akademik mahasiswa sangat kompleks, jadi semua parameter bernilai lebih dari 0 dan tidak ada maba yang masuk. Dari grafik dapat dilihat bahwa banyaknya mahasiswa yang mengambil mata kuliah maksimal tahun ke i (dengan i = 1,2,3,4) akan menuju ke titik equilibriumnya yaitu (0, 0, 0, 0).

# %%
from scipy.integrate import odeint
import numpy as np
import matplotlib.pyplot as plt
from pandas import DataFrame

def odes(x,t):
    #constan
    a = 0.6
    b = 0.6
    gama = 0.6
    r = 0.2
    k = 0.075
    s = 0.2
    f = 0.075
    u = 15
    mu1 = 0.05
    mu2 = 0.025
    mu3 = 0.05
    mu4 = 0.01
    p1 = 0.05
    p2 = 0.075
    p3 = 0.2
    p4 = 0.4
    q1 = 0.075
    q2 = 0.2
    q3 = 0.2
    

    #vector element
    A = x[0]
    B = x[1]
    C = x[2]
    D = x[3]
    
    # persamaan 
    dAdt = u - (a + r + mu1 + p1)*A - k*A*C + q1*D
    dBdt = a*A - (b + s + mu2 + p2)*B - f*B*D + q2*D
    dCdt = r*A + b*B - (gama + mu3 + p3)*C + k*A*C + q3*D
    dDdt = gama*C - (q1+q2+q3+mu4+p4)*D + f*B*D + s*B
    
    return (dAdt, dBdt, dCdt, dDdt)

#nilai awal (jumlah populasi awal)
x0=[10,10,10,10] 

#grafik waktu
t = np.linspace(0,20,10000)
x = odeint(odes,x0,t)

A = x[:,0]
B = x[:,1]
C = x[:,2]
D = x[:,3]

data={'t':t,'A':A, 'B':B, 'C':C, 'D':D}
print(DataFrame(data))

#plot 
plt.figure(figsize=(10,6))
plt.plot(t,A, label='Mengambil mata kuliah maksimal tahun ke 1', color='green')
plt.plot(t,B, label='Mengambil mata kuliah maksimal tahun ke 2', color='red')
plt.plot(t,C, label='Mengambil mata kuliah maksimal tahun ke 3', color='blue')
plt.plot(t,D, label='Mengambil mata kuliah maksimal tahun ke 4', color='yellow')
plt.legend()
plt.grid()
plt.title("Kasus 6")
plt.savefig('Kasus 6.png',dpi = 500)
plt.show()
# Out:
#               t          A          B          C          D
# 0      0.000000  10.000000  10.000000  10.000000  10.000000
# 1      0.002000   9.998490   9.983018  10.017991  10.013294
# 2      0.004000   9.996960   9.966076  10.035961  10.026574
# 3      0.006001   9.995410   9.949173  10.053908  10.039840
# 4      0.008001   9.993840   9.932310  10.071835  10.053091
# ...         ...        ...        ...        ...        ...
# 9995  19.991999   6.629797   3.301596  21.355246  21.136565
# 9996  19.993999   6.629797   3.301596  21.355248  21.136568
# 9997  19.996000   6.629797   3.301595  21.355250  21.136571
# 9998  19.998000   6.629796   3.301595  21.355251  21.136574
# 9999  20.000000   6.629796   3.301595  21.355253  21.136577
#
# [10000 rows x 5 columns]

# %% [markdown]
# Interpretasi
#
# nilai awal semua kelas yaitu 10, pada kasus 6 ini diasumsikan bahwa alur akademik mahasiswa sangat kompleks, jadi semua parameter bernilai lebih dari 0 dan terdapat ada maba yang masuk. Dari grafik dapat dilihat bahwa banyaknya mahasiswa yang mengambil mata kuliah maksimal tahun ke i (dengan i = 1,2,3,4) akan menuju ke titik yang berbeda beda.
